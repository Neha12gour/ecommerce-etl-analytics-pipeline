# %%
import pandas as pd
import numpy as np
import requests

# %%
products_url = "https://dummyjson.com/products"
users_url = "https://dummyjson.com/users"
carts_url = "https://dummyjson.com/carts"

# %%
#products
res1 = requests.get(products_url)
print("Products Status: ", res1.status_code)

if res1.status_code == 200:
    products_data = res1.json()['products']
    df_products = pd.DataFrame(products_data)
# Out:
# Products Status:  200

# %%
#user
res2 = requests.get(users_url)
print("Users Status: ", res2.status_code)

if res2.status_code == 200:
    users_data = res2.json()['users']
    df_users = pd.DataFrame(users_data)
# Out:
# Users Status:  200

# %%
#carts
res3 = requests.get(carts_url)
print("Carts Status: ", res3.status_code)

if res3.status_code == 200:
    carts_data = res3.json()['carts']
    df_carts = pd.DataFrame(carts_data)
# Out:
# Carts Status:  200

# %%
df_products.head()
# Out:
#    id                          title  \
# 0   1  Essence Mascara Lash Princess
# 1   2  Eyeshadow Palette with Mirror
# 2   3                Powder Canister
# 3   4                   Red Lipstick
# 4   5                Red Nail Polish
#
#                                          description category  price  \
# 0  The Essence Mascara Lash Princess is a popular...   beauty   9.99
# 1  The Eyeshadow Palette with Mirror offers a ver...   beauty  19.99
# 2  The Powder Canister is a finely milled setting...   beauty  14.99
# 3  The Red Lipstick is a classic and bold choice ...   beauty  12.99
# 4  The Red Nail Polish offers a rich and glossy r...   beauty   8.99
#
#    discountPercentage  rating  stock                   tags           brand  \
# 0               10.48    2.56     99      [beauty, mascara]         Essence
# 1               18.19    2.86     34    [beauty, eyeshadow]  Glamour Beauty
# 2                9.84    4.64     89  [beauty, face powder]    Velvet Touch
# ...

# %%
df_users.head()
# Out:
#    id firstName  lastName maidenName  age  gender  \
# 0   1     Emily   Johnson      Smith   29  female
# 1   2   Michael  Williams              36    male
# 2   3    Sophia     Brown              43  female
# 3   4     James     Davis              46    male
# 4   5      Emma    Miller    Johnson   31  female
#
#                               email             phone  username      password  \
# 0     emily.johnson@x.dummyjson.com  +81 965-431-3024    emilys    emilyspass
# 1  michael.williams@x.dummyjson.com  +49 258-627-6644  michaelw  michaelwpass
# 2      sophia.brown@x.dummyjson.com  +81 210-652-2785   sophiab   sophiabpass
# 3       james.davis@x.dummyjson.com  +49 614-958-9364    jamesd    jamesdpass
# 4       emma.miller@x.dummyjson.com  +91 759-776-1614     emmaj     emmajpass
#
#    ...                                            address         macAddress  \
# 0  ...  {'address': '626 Main Street', 'city': 'Phoeni...  47:fa:41:18:ec:eb
# ...

# %%
df_carts.head()
# Out:
#    id                                           products     total  \
# 0   1  [{'id': 162, 'title': 'Blue Frock', 'price': 2...  13037.88
# 1   2  [{'id': 86, 'title': 'Man Short Sleeve Shirt',...    139.93
# 2   3  [{'id': 24, 'title': 'Fish Steak', 'price': 14...   1794.85
# 3   4  [{'id': 92, 'title': 'Sports Sneakers Off Whit...    689.93
# 4   5  [{'id': 161, 'title': 'Samsung Galaxy Tab Whit...   1467.88
#
#    discountedTotal  userId  totalProducts  totalQuantity
# 0         11510.81       1              4             12
# 1           125.70       2              2              7
# 2          1625.77       3              6             15
# 3           636.81       4              2              7
# 4          1205.80       5              3             12

# %%
df_products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    30 non-null     int64
#  1   title                 30 non-null     object
#  2   description           30 non-null     object
#  3   category              30 non-null     object
#  4   price                 30 non-null     float64
#  5   discountPercentage    30 non-null     float64
#  6   rating                30 non-null     float64
#  7   stock                 30 non-null     int64
#  8   tags                  30 non-null     object
#  9   brand                 15 non-null     object
#  10  sku                   30 non-null     object
#  11  weight                30 non-null     int64
#  12  dimensions            30 non-null     object
#  13  warrantyInformation   30 non-null     object
#  14  shippingInformation   30 non-null     object
# ...

# %%
df_users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 28 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          30 non-null     int64
#  1   firstName   30 non-null     object
#  2   lastName    30 non-null     object
#  3   maidenName  30 non-null     object
#  4   age         30 non-null     int64
#  5   gender      30 non-null     object
#  6   email       30 non-null     object
#  7   phone       30 non-null     object
#  8   username    30 non-null     object
#  9   password    30 non-null     object
#  10  birthDate   30 non-null     object
#  11  image       30 non-null     object
#  12  bloodGroup  30 non-null     object
#  13  height      30 non-null     float64
#  14  weight      30 non-null     float64
#  15  eyeColor    30 non-null     object
#  16  hair        30 non-null     object
#  17  ip          30 non-null     object
#  18  address     30 non-null     object
# ...

# %%
df_carts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               30 non-null     int64
#  1   products         30 non-null     object
#  2   total            30 non-null     float64
#  3   discountedTotal  30 non-null     float64
#  4   userId           30 non-null     int64
#  5   totalProducts    30 non-null     int64
#  6   totalQuantity    30 non-null     int64
# dtypes: float64(2), int64(4), object(1)
# memory usage: 1.8+ KB

# %%
df_products = df_products[['id', 'title', 'price', 'category', 'rating']]

# %%
df_products.rename(columns = {'id':'product_id'}, inplace = True)

# %%
df_products.head()
# Out:
#    product_id                          title  price category  rating
# 0           1  Essence Mascara Lash Princess   9.99   beauty    2.56
# 1           2  Eyeshadow Palette with Mirror  19.99   beauty    2.86
# 2           3                Powder Canister  14.99   beauty    4.64
# 3           4                   Red Lipstick  12.99   beauty    4.36
# 4           5                Red Nail Polish   8.99   beauty    4.32

# %%
# full name
df_users['full_name'] = df_users['firstName'] + " " + df_users['lastName']

# %%
#extract city from nested Address
df_users['city'] = df_users['address'].apply(lambda x: x['city'])

# %%
df_users = df_users[['id', 'full_name', 'city', 'gender', 'age']]

# %%
df_users.rename(columns = {'id':'user_id'}, inplace=True)

# %%
df_users.head()
# Out:
#    user_id         full_name          city  gender  age
# 0        1     Emily Johnson       Phoenix  female   29
# 1        2  Michael Williams       Houston    male   36
# 2        3      Sophia Brown    Washington  female   43
# 3        4       James Davis       Seattle    male   46
# 4        5       Emma Miller  Jacksonville  female   31

# %%
#transforming  Carts
#convert nested list to rows
df_carts= df_carts.explode('products')

# %%
df_carts.head()
# Out:
#    id                                           products     total  \
# 0   1  {'id': 162, 'title': 'Blue Frock', 'price': 29...  13037.88
# 0   1  {'id': 113, 'title': 'Generic Motorcycle', 'pr...  13037.88
# 0   1  {'id': 122, 'title': 'iPhone 6', 'price': 299....  13037.88
# 0   1  {'id': 138, 'title': 'Baseball Ball', 'price':...  13037.88
# 1   2  {'id': 86, 'title': 'Man Short Sleeve Shirt', ...    139.93
#
#    discountedTotal  userId  totalProducts  totalQuantity
# 0         11510.81       1              4             12
# 0         11510.81       1              4             12
# 0         11510.81       1              4             12
# 0         11510.81       1              4             12
# 1           125.70       2              2              7

# %%
#extract product id and quantity
df_carts['product_id'] = df_carts['products'].apply(lambda x: x['id'])
df_carts['quantity'] = df_carts['products'].apply(lambda x: x['quantity'])

# %%
df_carts.drop(columns = ['products'], inplace = True)

# %%
#rename columns
df_carts.rename(columns = {'id':'cart_id', 'userId':'user_id'}, inplace=True)

# %%
df_carts.head()
# Out:
#    cart_id     total  discountedTotal  user_id  totalProducts  totalQuantity  \
# 0        1  13037.88         11510.81        1              4             12
# 0        1  13037.88         11510.81        1              4             12
# 0        1  13037.88         11510.81        1              4             12
# 0        1  13037.88         11510.81        1              4             12
# 1        2    139.93           125.70        2              2              7
#
#    product_id  quantity
# 0         162         4
# 0         113         3
# 0         122         3
# 0         138         2
# 1          86         5

# %% [markdown]
# ### Feature Engineering

# %%
#merge with product table to get price
df_carts = df_carts.merge(df_products, on='product_id', how='left')

# %%
#revenue calculation
df_carts['revenue'] = df_carts['price'] * df_carts['quantity']

# %%
df_carts.head()
# Out:
#    cart_id     total  discountedTotal  user_id  totalProducts  totalQuantity  \
# 0        1  13037.88         11510.81        1              4             12
# 1        1  13037.88         11510.81        1              4             12
# 2        1  13037.88         11510.81        1              4             12
# 3        1  13037.88         11510.81        1              4             12
# 4        2    139.93           125.70        2              2              7
#
#    product_id  quantity title  price category  rating  revenue
# 0         162         4   NaN    NaN      NaN     NaN      NaN
# 1         113         3   NaN    NaN      NaN     NaN      NaN
# 2         122         3   NaN    NaN      NaN     NaN      NaN
# 3         138         2   NaN    NaN      NaN     NaN      NaN
# 4          86         5   NaN    NaN      NaN     NaN      NaN

# %%
df_carts.duplicated().sum()
# Out:
# np.int64(1)

# %%
df_carts.drop_duplicates(inplace = True)
df_users.drop_duplicates(inplace = True)
df_products.drop_duplicates(inplace = True)

# %%
# !pip install sqlalchemy pymysql
# Out:
# ...
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sqlalchemy import create_engine
from urllib.parse import quote_plus

password = quote_plus("WRITE YOUR PASSWORD")

engine = create_engine(f"mysql+pymysql://root:{password}@localhost:3306/ecommerce")

engine.connect()

print("✅ Connected successfully!")
# Out:
# ✅ Connected successfully!

# %%
df_products.to_sql("products", engine, if_exists="replace", index=False)
df_users.to_sql("users", engine, if_exists="replace", index=False)
df_carts.to_sql("orders", engine, if_exists="replace", index=False)
# Out:
# 113

# %%
df_products.to_csv("products.csv",index=False)

# %%
df_users.to_csv("users.csv",index=False)

# %%
df_carts.to_csv("carts.csv",index=False)
